# %%
import pandas as pd
import numpy as np

# %%
first=pd.read_csv('first_tr.csv',header=None)
second=pd.read_csv('second_tr.csv',header=None)

# %%
first_test=first.sample(frac=0.3,axis=0,random_state=10)
second_test=second.sample(frac=0.3,axis=0,random_state=10)
first.drop(first_test.index,inplace=True)
second.drop(second_test.index,inplace=True)
#df=data.sample(frac=0.3,axis=0,random_state=10)
#df.index
first
#X = testData[:, :-1]
#y = testData[:, -1]
# Out:
#          0        1        2        3        4        5        6        7   \
# 0   27.4100  25.3200  27.7900  26.1500  26.0300  27.4500  26.1600  27.4200
# 3   27.3134  25.6697  27.8742  26.0036  26.1312  27.3928  25.8194  27.5780
# 4   26.9583  26.1170  27.7840  25.5791  25.8870  27.3360  24.5940  26.9736
# 6   27.3925  25.7596  27.7553  26.0260  26.2103  27.4545  25.7668  27.5661
# 8   25.8005  25.4376  28.2882  26.0980  26.4758  27.2945  27.4830  27.0084
# 9   27.0887  25.7559  28.5142  27.4250  26.5444  27.3077  28.8760  26.2709
# 10  26.7163  25.6667  28.6142  26.8970  26.5858  27.4798  28.3970  26.5923
# 13  27.3380  26.3093  28.6767  27.7665  26.0782  27.2950  28.2133  24.6161
# 14  26.1451  26.1399  28.4459  26.5851  26.7722  27.1891  28.0984  26.6742
# 15  25.3856  26.0159  28.5929  26.1131  26.7601  27.5576  27.5967  26.8263
# 16  27.2192  25.4099  28.5428  27.5318  26.4594  27.5546  29.0234  26.2791
# ...

# %%
testData=pd.concat([first_test,second_test],ignore_index=True)
testData
# Out:
#          0        1        2        3        4        5        6        7   \
# 0   27.7217  26.4275  27.5340  26.2608  26.2631  27.3880  25.5828  27.4730
# 1   27.3994  26.0631  28.1126  26.0350  26.1165  27.5542  25.4360  27.3878
# 2   27.6561  26.7353  27.6801  26.2449  26.3653  27.4723  25.2856  27.3959
# 3   26.9516  26.8092  27.6671  25.6340  26.3420  27.1978  24.6598  27.4264
# 4   25.1905  25.6392  28.2172  26.0425  26.4348  27.3115  27.5318  26.2975
# 5   23.9665  26.4870  27.5050  25.3649  26.4508  27.0603  26.1509  25.6868
# 6   24.0231  26.7704  27.4757  25.3999  26.3554  27.1245  25.7573  25.0913
# 7   22.6940  25.6887  25.1008  23.9579  26.1434  25.7014  24.2035  25.2984
# 8   23.0057  25.9714  25.7052  24.3260  26.4100  26.1886  24.7468  25.5032
# 9   23.0877  25.5880  25.9979  24.3424  26.3019  26.2502  25.0211  25.4326
# 10  23.1486  26.6986  26.5773  24.3877  25.9803  26.2394  23.9245  24.5386
# ...

# %%
first
# Out:
#          0        1        2        3        4        5        6        7   \
# 0   27.4100  25.3200  27.7900  26.1500  26.0300  27.4500  26.1600  27.4200
# 3   27.3134  25.6697  27.8742  26.0036  26.1312  27.3928  25.8194  27.5780
# 4   26.9583  26.1170  27.7840  25.5791  25.8870  27.3360  24.5940  26.9736
# 6   27.3925  25.7596  27.7553  26.0260  26.2103  27.4545  25.7668  27.5661
# 8   25.8005  25.4376  28.2882  26.0980  26.4758  27.2945  27.4830  27.0084
# 9   27.0887  25.7559  28.5142  27.4250  26.5444  27.3077  28.8760  26.2709
# 10  26.7163  25.6667  28.6142  26.8970  26.5858  27.4798  28.3970  26.5923
# 13  27.3380  26.3093  28.6767  27.7665  26.0782  27.2950  28.2133  24.6161
# 14  26.1451  26.1399  28.4459  26.5851  26.7722  27.1891  28.0984  26.6742
# 15  25.3856  26.0159  28.5929  26.1131  26.7601  27.5576  27.5967  26.8263
# 16  27.2192  25.4099  28.5428  27.5318  26.4594  27.5546  29.0234  26.2791
# ...

# %%
second
# Out:
#          0        1        2        3        4        5        6        7   \
# 0   23.4596  27.5844  27.3405  24.3909  26.5343  26.9211  23.6251  25.2119
# 1   23.1711  25.7650  25.5651  24.4900  26.0636  26.1330  24.8875  24.8805
# 4   22.7498  25.5969  25.8667  24.0794  26.1053  26.2353  24.7283  25.0470
# 6   23.9818  25.0685  26.5395  24.2406  26.4365  26.0632  24.1961  27.5108
# 8   22.9886  25.9987  25.6263  24.3248  26.3048  26.1637  24.6330  25.1964
# 9   23.4092  27.8436  25.8501  24.5313  27.3427  26.6565  24.2575  25.9465
# 10  23.3967  27.5689  26.6845  24.5475  26.6486  26.6173  24.0820  25.2003
# 11  23.8174  27.3756  27.4047  25.0077  26.5751  27.0803  24.6269  25.1323
# 15  22.7859  25.7283  24.6317  23.8839  26.1235  25.5187  24.2295  25.1357
# 16  22.8857  26.0316  24.3912  23.6414  26.7638  25.4177  23.4410  25.9391
# 17  22.8782  25.5997  25.0589  24.0236  26.0864  25.8274  24.5841  24.9657
# ...

# %%
first.to_csv('first_tr.csv',header=None,index=None)
second.to_csv('second_tr.csv',header=None,index=None)
testData.to_csv('test_MD.csv',header=None,index=None)
