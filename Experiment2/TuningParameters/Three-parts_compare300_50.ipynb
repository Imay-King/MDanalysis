# %% [markdown]
# #### Max_sample=50

# %%
import MDAnalysis as mda
import MDAnalysis.coordinates.DCD
import MDAnalysis.coordinates.DCD as dcd
import numpy as np
import pandas as pd

# %%
topology='ala13_mini_conv.pdb'
trajectory='ala13_md.dcd'
universe=mda.Universe(topology,trajectory)
ref=mda.Universe(topology)

# %%
trajectory_res='ala13_md_res_ca.dcd'

# %%
import MDAnalysis.analysis.rms
import matplotlib.pyplot as plt

# %%
rmsd_ref=[]

# %%
#for time_step in universe.trajectory[::5]:
#non_hydrogen_data=universe.select_atoms('resid 10:13 and not name H*')
rmsd_no_aling=MDAnalysis.analysis.rms.rmsd(universe.select_atoms('resid 5:9 and not name H*').positions, ref.select_atoms('resid 5:9 and not name H*').positions)
#print(universe.trajectory.time)
rmsd_ref.append(rmsd_no_aling)
print(rmsd_ref)
len(rmsd_ref)
#rmsd_ref_1=np.array(rmsd_ref)
#len(rmsd_ref)
# Out:
# [0.7073595274695684, 0.7448850533196607, 1.0470411355319662, 0.49100618737918306, 1.2807768907939177, 1.2607825878242727, 1.6159479359825828, 1.310163198962215, 1.3907030790653534, 1.0834383431662011, 0.7688261908667393, 0.8858093750356818, 0.8602355425423657, 0.6550107883449444, 0.638371328971174, 0.6301360313540249, 0.7516559907304547, 0.8059528733784502, 0.7479271711387463, 0.8618501327787771, 0.7849561000846896, 0.7152352561571628, 0.6395603791542461, 0.7534666784978138, 0.5596842091258885, 0.6543431610821487, 0.7199017370677753, 0.9068545657366596, 0.7193761530260279, 0.7136389708867119, 0.6939135223823295, 0.5374631641628382, 0.6370501324568301, 0.7512437394775893, 0.4734757695971958, 0.5789310080776947, 0.6751696453624264, 0.6413079949122832, 0.6062242205427602, 0.6247558589598172, 0.6332151676194807, 0.4655496037330382, 0.7988611661054207, 0.6651300949651229, 0.5164909773265591, 0.8309255481027757, 0.650650822471304, 0.8888704521887066, 0.6340806367253732, 0.7249273310788589,
# ...

# %%
R1 = MDAnalysis.analysis.rms.RMSD(universe,
                                 select='resid 1:4 and not name H*')
R1.run()
R2 = MDAnalysis.analysis.rms.RMSD(universe,
                                 select='resid 5:9 and not name H*')
R2.run()
R3 = MDAnalysis.analysis.rms.RMSD(universe,
                                 select='resid 10:13 and not name H*')
R3.run()

# %%
rmsd2 = R2.rmsd.T   # transpose makes it easier for plotting
time=rmsd2[1][::5]
frames=np.arange(len(time))
neg2=[6, 7, 8, 9, 53, 61, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 113, 158, 159, 160, 211, 213, 214, 231, 234, 247, 262, 263, 265, 266, 267, 268, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 336, 337, 338, 339, 354, 382, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 407, 408, 410, 418, 419, 420, 437, 442, 462, 466, 478, 481, 489, 492, 497]
plt.figure(figsize=(25,15))
plt.plot(frames, rmsd2[2][::5], 'b--',  label="original frames")
for i in neg2:
    plt.plot(i,rmsd2[2][::5][i],'o',c='red')
plt.legend(loc="best")
plt.xlabel("Frames")
plt.ylabel(r"RMSD ($\AA$)")

my_x_ticks = np.arange(0, 500, 10)

plt.xticks(my_x_ticks)
plt.show()

# %%
a=rmsd2[2][::5]
a.shape
# Out:
# (500,)

# %%
rmsd1 = R1.rmsd.T   # transpose makes it easier for plotting
time=rmsd1[1][::5]
frames=np.arange(len(time))
neg1=[5, 6, 8, 9, 23, 46, 53, 72, 74, 75, 76, 77, 78, 79, 80, 81, 84, 86, 87, 88, 89, 91, 92, 93, 94, 95, 96, 98, 99, 100, 101, 104, 105, 106, 113, 114, 115, 120, 131, 158, 159, 160, 178, 179, 182, 211, 213, 214, 230, 242, 247, 248, 254, 256, 258, 265, 267, 268, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 327, 328, 330, 331, 332, 336, 338, 339, 343, 348, 356, 382, 386, 398, 399, 400, 401, 402, 403, 407, 408, 409, 410, 411, 419, 430, 437, 441, 454, 457, 460, 461, 462, 463, 464, 468, 477, 493, 497]
plt.figure(figsize=(25,15))
plt.plot(frames, rmsd1[2][::5], 'b--',  label="original frames")
for i in neg1:
    plt.plot(i,rmsd1[2][::5][i],'o',c='red')
plt.legend(loc="best")
plt.xlabel("Frames")
plt.ylabel(r"RMSD ($\AA$)")

my_x_ticks = np.arange(0, 500, 10)

plt.xticks(my_x_ticks)
plt.show()

# %%
rmsd3 = R3.rmsd.T   # transpose makes it easier for plotting
time=rmsd3[1][::5]
frames=np.arange(len(time))
neg3=[4, 5, 6, 7, 8, 9, 10, 55, 61, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 173, 231, 234, 247, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 338, 339, 343, 344, 354, 382, 394, 396, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 418, 419, 420, 430, 437, 461, 462, 464, 465, 466, 467, 478, 487]
plt.figure(figsize=(25,15))
plt.plot(frames, rmsd3[2][::5], 'b--',  label="original frames")
for i in neg3:
    plt.plot(i,rmsd3[2][::5][i],'o',c='red')
plt.legend(loc="best")
plt.xlabel("Frames")
plt.ylabel(r"RMSD ($\AA$)")

my_x_ticks = np.arange(0, 500, 10)

plt.xticks(my_x_ticks)
plt.show()
