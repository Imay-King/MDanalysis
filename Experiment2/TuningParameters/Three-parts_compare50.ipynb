# %% [markdown]
# #### Max_sample=50

# %%
import MDAnalysis as mda
import MDAnalysis.coordinates.DCD
import MDAnalysis.coordinates.DCD as dcd
import numpy as np
import pandas as pd

# %%
topology='ala13_mini_conv.pdb'
trajectory='ala13_md.dcd'
universe=mda.Universe(topology,trajectory)

# %%
import MDAnalysis.analysis.rms
import matplotlib.pyplot as plt

# %%
R1 = MDAnalysis.analysis.rms.RMSD(universe,
                                 select='resid 1:4 and not name H*')
R1.run()
R2 = MDAnalysis.analysis.rms.RMSD(universe,
                                 select='resid 5:9 and not name H*')
R2.run()
R3 = MDAnalysis.analysis.rms.RMSD(universe,
                                 select='resid 10:13 and not name H*')
R3.run()

# %%
rmsd1 = R1.rmsd.T   # transpose makes it easier for plotting
time=rmsd1[1][::5]
frames=np.arange(len(time))
neg1=[6, 8, 9, 76, 77, 78, 81, 92, 95, 99, 100, 101, 104, 105, 113, 158, 159, 160, 214, 230, 247, 254, 256, 268, 270, 272, 276, 280, 281, 282, 283, 284, 285, 289, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 320, 322, 330, 338, 339, 382, 399, 402, 403, 407, 410, 411, 454, 462, 477]
plt.figure(figsize=(25,15))
plt.plot(frames, rmsd1[2][::5], 'b--',  label="original frames")
for i in neg1:
    plt.plot(i,rmsd1[2][::5][i],'o',c='red')
plt.legend(loc="best")
plt.xlabel("Frames")
plt.ylabel(r"RMSD ($\AA$)")

my_x_ticks = np.arange(0, 500, 10)

plt.xticks(my_x_ticks)
plt.show()

# %%
rmsd2 = R2.rmsd.T   # transpose makes it easier for plotting
time=rmsd2[1][::5]
frames=np.arange(len(time))
neg2=[6, 8, 9, 61, 71, 72, 74, 75, 76, 77, 78, 79, 81, 82, 86, 92, 93, 95, 96, 97, 98, 99, 100, 101, 104, 105, 159, 160, 214, 231, 234, 265, 266, 267, 268, 270, 272, 276, 278, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 320, 321, 322, 323, 329, 330, 331, 332, 338, 339, 398, 399, 400, 401, 402, 407, 410, 419, 420, 437, 442, 462, 497]
plt.figure(figsize=(25,15))
plt.plot(frames, rmsd2[2][::5], 'b--',  label="original frames")
for i in neg2:
    plt.plot(i,rmsd2[2][::5][i],'o',c='red')
plt.legend(loc="best")
plt.xlabel("Frames")
plt.ylabel(r"RMSD ($\AA$)")

my_x_ticks = np.arange(0, 500, 10)

plt.xticks(my_x_ticks)
plt.show()

# %%
rmsd3 = R3.rmsd.T   # transpose makes it easier for plotting
time=rmsd3[1][::5]
frames=np.arange(len(time))
neg3=[6, 8, 74, 75, 77, 80, 81, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 99, 100, 101, 263, 265, 266, 267, 268, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 410, 420, 462, 466]
plt.figure(figsize=(25,15))
plt.plot(frames, rmsd3[2][::5], 'b--',  label="original frames")
for i in neg3:
    plt.plot(i,rmsd3[2][::5][i],'o',c='red')
plt.legend(loc="best")
plt.xlabel("Frames")
plt.ylabel(r"RMSD ($\AA$)")

my_x_ticks = np.arange(0, 500, 10)

plt.xticks(my_x_ticks)
plt.show()
